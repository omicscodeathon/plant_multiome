# %%
# !pip install pandas biopython seaborn
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 1.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 292 kB 2.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.3 MB 2.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 41.6 MB 1.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 895 kB 1.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 2.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import seaborn as sn
import Bio

# %%
eukaryotes = pd.read_csv('eukaryotes.csv')
organelles = pd.read_csv('organelles.csv')

# %%
def get_group(taxa):
    return taxa.split(';')[1]

# %%
eukaryotes['Organism Groups']=eukaryotes['Organism Groups'].apply(get_group)

# %%
organelles['Organism Groups']=organelles['Organism Groups'].apply(get_group)

# %%
Animals_chr = eukaryotes[eukaryotes["Organism Groups"] == 'Animals']

# %%
Animals_mitos = organelles[organelles["Organism Groups"] == 'Animals']

# %%
Animals = pd.merge(Animals_chr,Animals_mitos, on='BioProject')

# %%
Animals
# Out:
#            #Organism Name_x Organism Groups_x       Strain_x   BioSample_x  \
# 0             Aedes aegypti           Animals       LVP_AGWG  SAMN07177802
# 1          Aedes albopictus           Animals            FPA  SAMN11317331
# 2            Apis mellifera           Animals            DH4  SAMN09259743
# 3              Homo sapiens           Animals            NaN  SAMN03255769
# 4         Rattus norvegicus           Animals    BN/NHsdMcwi  SAMN16261960
# ...                     ...               ...            ...           ...
# 1254           Homo sapiens           Animals        NA24385  SAMN03283347
# 1255  Spodoptera frugiperda           Animals            Sf9  SAMN06658935
# 1256           Homo sapiens           Animals            NaN  SAMD00243993
# 1257           Homo sapiens           Animals       mHomSap3  SAMN12568975
# 1258           Homo sapiens           Animals  ATCC CRL-2325  SAMN10102574
#
# ...

# %%
Plants_mitos = organelles[(organelles["Organism Groups"] != 'Animals') & (organelles['Type'] == 'mitochondrion')]

# %%
Plants_pt = organelles[(organelles["Organism Groups"] != 'Animals') & (organelles['Type'] != 'mitochondrion')]

# %%
Plants = pd.merge(Plants,Plants_pt,on='BioProject')

# %%
Plants
# Out:
#                   #Organism Name_x Organism Groups_x                 Strain_x  \
# 0              Medicago truncatula            Plants                      NaN
# 1                   Brassica napus            Plants                      NaN
# 2                   Brassica napus            Plants                      NaN
# 3                Helianthus annuus            Plants                      NaN
# 4                   Lactuca sativa            Plants                      NaN
# 5                Nicotiana tabacum            Plants                      NaN
# 6                Manihot esculenta            Plants                      NaN
# 7       Vigna radiata var. radiata            Plants                      NaN
# 8     Daucus carota subsp. sativus            Plants                      NaN
# 9               Eucalyptus grandis            Plants            ANBG69807.140
# 10             Phoenix dactylifera            Plants                      NaN
# ...
